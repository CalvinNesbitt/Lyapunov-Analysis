# %%
# Notebook for computing Lyapunov Spectrum of the Lorenz 63 system
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt 
from scipy.integrate import odeint
from scipy.linalg import expm
from mpl_toolkits.mplot3d import Axes3D

# %%
# Function to ensure QR decomposition has positive diagonals

def posQR(M):
    """ Returns QR decomposition of a matrix with positive diagonals on R.
    Parameter, M: Array that is being decomposed
    """
    Q, R = np.linalg.qr(M) # Performing QR decomposition
    signs = np.diag(np.sign(np.diagonal(R))) # Matrix with signs of R diagonal on the diagonal
    Q, R = np.dot(Q, signs), np.dot(signs, R) # Ensuring R Diagonal is positive
    return Q, R

# %%
# First we solve and plot L63

# %%
# L63 Definition

#Parameters
a = 10.0
b = 8/3
c = 28.0
p = [a, b, c]

def L63(state, t, p):
    """ ODEs defining Lorenz 63 system.
    Parameter, state: current state.
    Parameter, t: time.
    Parameter, p: array, parameters for L63.
    """
    [a, b, c] = p
    x, y, z = state
    dxdt = a * (y - x)
    dydt = (c * x) - y - (x * z)
    dzdt = (x * y) - (b * z)
    dudt = np.array([dxdt, dydt, dzdt])
    return dudt

# %%
# Time Parameters

dt = 0.01 # Time step 
k = 4 # Number of steps that 'the propagator' moves you forward
steps = int(1.e5 * k) # Controls convergence
time = np.arange(0, steps * dt, dt)

# %%
# Solving L63 Numerically using odeint

IC = np.array([1.0, 2.0, 3.0]) 
solution = odeint(L63, IC, time, (p,))

# Plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(solution[:, 0], solution[:, 1], solution[:, 2])
plt.show()

# %%
# Calculating the Jacobian at each point of the solution

# %%
def Jacobian(location, parameters):
    """Returns the jacobian matrix at a given point of L63.
    Param, location, array: [x, y, z] coordinates.
    Parameters, parameters, L63 parameters.
    """
    [a, b, c] = parameters
    [x, y, z] = location
    row1 = np.array([-a, a, 0])
    row2 = np.array([c - z, -1, -x])
    row3 = np.array([y, x, -b])
    J = np.array([row1, row2, row3])
    return J

# Test of Jacobian Function
# location = [2, 0, 1]
# print(Jacobian(location, [a, b, c]))

# %%
# Storing time series of Jacobians
# Note that J(step * dt) = Jacobians[:, :, step]

jacobians = np.zeros((3, 3, time.shape[0])) # Time series of Jacobian matrix. Indexed as (row, column, step)
for t in range(time.shape[0]):
#     print(f'Solution to Lorenz at step {t} (time {time[t]}) is\n {solution[t]}\n\n')
#     print(f'Jacobian at step {t} (time {time[t]}) is\n{Jacobian(solution[t], [a, b, c])}\n\n')
    jacobians[:, :, t] = Jacobian(solution[t], [a, b, c])
#     print(f'Stored Jacobian is\n{jacobians[:, :, t]}\n\n')

# %%
# Function to define the propagator (product of jacobians)

def Propagator(step, k, jacobians):
    """ Propagator matrix F(step, step + k). Evolves solutions of tangent linear equation forward in time.
    Param, step, integer: step we're caluclating propator at
    Param, k, how many steps we push forward.
    """
    F = jacobians[:, :, step]
    #print(f'At step {step} the jacobian is\n {jacobians[:, :, step]}.\n\n')
    for i in range(1, k):
        #print(f'At step {step + i} the jacobian is\n {jacobians[:, :, step + i]}.\n\n')
        F = np.dot(F, jacobians[:, :, step + i])
    return F

# k = 3
# step = 4
# print(Propagator(step, k, jacobians))
# Jk = jacobians[:, :, step]
# Jk1 = jacobians[:, :, step + 1]
# Jk2 = jacobians[:, :, step + 2]
# print(reduce(np.dot, [Jk, Jk1, Jk2]))

# %%
# Benettin Algorithm for calculating the Lyapunov Spectrum

# %%
oldM = np.identity(3) # Initialising an orthogonal matrix
lyap = np.zeros(3) # Running sum of FTLEs
lyapSum = np.zeros((int(steps/k), 3)) # For storing time series of running sum
for i in range(0, steps, k):
    F = Propagator(i, k, jacobians)
    newM = np.dot(F, oldM) # Pushing orthogonal matrix forward with propagator
    Q, R = posQR(newM) # Performing Q, R decomposition with positive diagonals
    #print(f'At step {i}\n\n Q is\n\n{Q}\n\n and R is\n\n{R}\n\n')
    lyap = np.log(np.diag(R)) + lyap # Running sum
    lyapSum[int(i/k)] = lyap # Storing time series of running sum

    
print(f'Lyapunov exponents are {lyap/time[-1]}')
# Out:
# Lyapunov exponents are [269.54877791 201.18391886 146.78870256]

# %%
# Plots of Running Average of FTLE

# %%
from matplotlib import rc
rc('text', usetex=True)

j = 100 # Controls time that plots will start from

# First LE
plt.plot(np.arange(0, steps, k)[k * j:], lyapSum[k * j:, 0]/(dt * np.arange(0, steps, k)[k * j:]))
plt.xlabel('Time')
plt.ylabel('$\lambda_1$')
plt.title('Running $\lambda_1$ Average')

# Second LE
plt.figure()
plt.plot(np.arange(0, steps, k)[k * j:], lyapSum[k * j:, 1]/(dt * np.arange(0, steps, k)[k * j:]))
plt.xlabel('Time')
plt.ylabel('$\lambda_2$')
plt.title('Running $\lambda_2$ Average')

# Third LE
plt.figure()
plt.plot(np.arange(0, steps, k)[k * j:], lyapSum[k * j:, 2]/(dt * np.arange(0, steps, k)[k * j:]))
plt.xlabel('Time')
plt.ylabel('$\lambda_3$')
plt.title('Running $\lambda_3$ Average')
# Out:
# Text(0.5, 1.0, 'Running $\\lambda_3$ Average')
